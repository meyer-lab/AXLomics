# %%
from msresist.figures.figure5 import *

# %%
matplotlib.rcParams['font.sans-serif'] = "Arial"
sns.set(style="whitegrid", font_scale=1, color_codes=True, palette="colorblind", rc={"grid.linestyle": "dotted", "axes.linewidth": 0.6})

# %%
plot_AXLspecificity_heatmap(type="Heatmap")

# %%
_, ax = plt.subplots(1, 1, figsize=(5, 5))
plot_AXLspecificity_heatmap(type="Logo", ax=ax)

# %%
plotViolin_HuTyr_vs_AXLspikedIn()
# Out:
# /home/creixell/AXLomics/msresist/figures/figure5.py:61: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(
# T-statistic: 7.0679
# P-value: 0.00000000
# Statistically significant difference: True
#
# AXL spiked-in: mean=-0.2244, std=1.4062, n=558
# pTyr-Var: mean=-0.6548, std=1.2595, n=9684

# %%
plot_Specificity_Enrichment_by_DDMC_cluster()
# Out:
# /home/creixell/AXLomics/msresist/pre_processing.py:121: FutureWarning: The provided callable <function mean at 0x7f387029ac00> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   return pd.pivot_table(X, values=values, index=indices, aggfunc=np.mean)
# /home/creixell/AXLomics/msresist/pre_processing.py:284: FutureWarning: The provided callable <function mean at 0x7f387029ac00> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   X = pd.pivot_table(triplicates, values=triplicates[data_headers].columns, index=merging_indices, aggfunc=func_tri)
# /home/creixell/AXLomics/msresist/pre_processing.py:284: FutureWarning: The provided callable <function std at 0x7f387029ad40> is currently using SeriesGroupBy.std. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "std" instead.
#   X = pd.pivot_table(triplicates, values=triplicates[data_headers].columns, index=merging_indices, aggfunc=func_tri)
# /home/creixell/AXLomics/msresist/pre_processing.py:284: FutureWarning: The provided callable <function mean at 0x7f387029ac00> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   X = pd.pivot_table(triplicates, values=triplicates[data_headers].columns, index=merging_indices, aggfunc=func_tri)
# /home/creixell/AXLomics/msresist/pre_processing.py:121: FutureWarning: The provided callable <function mean at 0x7f387029ac00> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   return pd.pivot_table(X, values=values, index=indices, aggfunc=np.mean)
# 2025-08-08 17:09:59,999 [WARNING] Duplicated values found in preranked stats: 1.14% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2025-08-08 17:10:00,001 [INFO] Parsing data files for GSEA.............................
# 2025-08-08 17:10:00,001 [INFO] 0002 gene_sets have been filtered out when max_size=1000 and min_size=5
# 2025-08-08 17:10:00,002 [INFO] 0003 gene_sets used for further statistical testing.....
# 2025-08-08 17:10:00,003 [INFO] Start to run GSEA...Might take a while..................
# 2025-08-08 17:10:00,036 [INFO] Congratulations. GSEApy runs successfully................
#       Name Term        ES       NES NOM p-val FDR q-val FWER p-val   Tag %  \
# 0  prerank    2  0.324026  1.670377       0.0  0.004335      0.003  46/130
# 1  prerank    3  0.277152   1.38739  0.038627   0.03685      0.051  29/115
# 2  prerank    4 -0.269618 -1.265556  0.132597  0.108292   0.179012   32/77
#
#    Gene %                                         Lead_genes
# 0  26.52%  ARHGAP42;TJP2;NEDD9;TNK2;CTNND1;GPRC5C;RIN1;WA...
# 1  18.94%  TJP2;NEDD9;TNK2;CTNND1;RIN1;AXL;ANXA2;ARHGAP27...
# 2  32.95%  HNRNPA2B1;PI4KA;VTA1;RBM14;ZYX;ARHGDIA;STAT6;H...

# %%
plot_AXL_Screen_Results()
# Out:
# /home/creixell/AXLomics/msresist/pre_processing.py:121: FutureWarning: The provided callable <function mean at 0x7f387029ac00> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   return pd.pivot_table(X, values=values, index=indices, aggfunc=np.mean)
# /home/creixell/AXLomics/msresist/pre_processing.py:284: FutureWarning: The provided callable <function mean at 0x7f387029ac00> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   X = pd.pivot_table(triplicates, values=triplicates[data_headers].columns, index=merging_indices, aggfunc=func_tri)
# /home/creixell/AXLomics/msresist/pre_processing.py:284: FutureWarning: The provided callable <function std at 0x7f387029ad40> is currently using SeriesGroupBy.std. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "std" instead.
#   X = pd.pivot_table(triplicates, values=triplicates[data_headers].columns, index=merging_indices, aggfunc=func_tri)
# /home/creixell/AXLomics/msresist/pre_processing.py:284: FutureWarning: The provided callable <function mean at 0x7f387029ac00> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   X = pd.pivot_table(triplicates, values=triplicates[data_headers].columns, index=merging_indices, aggfunc=func_tri)
# /home/creixell/AXLomics/msresist/pre_processing.py:121: FutureWarning: The provided callable <function mean at 0x7f387029ac00> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   return pd.pivot_table(X, values=values, index=indices, aggfunc=np.mean)
# /home/creixell/AXLomics/msresist/figures/figure5.py:216: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels([500, 400, 300, 200, 100, 1])
