# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

# %%
matplotlib.rcParams['font.sans-serif'] = "Arial"
sns.set(style="whitegrid", font_scale=1, color_codes=True, palette="colorblind", rc={"grid.linestyle": "dotted", "axes.linewidth": 0.6})

# %%
from msresist.figures.figure3 import plot_InhDR_timepoint, plot_YAPinhibitorTimeLapse

_, ax = plt.subplots(1, 2, figsize=(10, 4))
plot_InhDR_timepoint(ax[0], "CX-4945", itp=18)
ax[0].set_title("CX-4945: CK2i")
plot_InhDR_timepoint(ax[1], "Volasertib", itp=18)
ax[1].set_title("Volasertib: PLK1")
plt.savefig("inh.svg")
